# %%
from outils import *
from hog import hog
import numpy as np

# %%
D = 10
N = 100
h = hog(D,N)

# %%
h.jouer(h.strategie_aveugle(),h.strategie_aveugle())
# Out:
# (113, 61)

# %%
def moyenne(strategie1,strategie2,name1,name2,steps=1000):
    def f1():
        score1,score2 = h.jouer(strategie1,strategie2)
        return 0 if score1 > score2 else 1
    
    def f2():
        score1,score2 = h.jouer(strategie1,strategie2)
        return 0 if score1 > score2 else 1
    
    a = np.zeros((steps))-1
    vfunc = np.vectorize(lambda x: f1())
    s1 = 1 - vfunc(a).sum()/steps
    
    """
    a = np.zeros((steps))-1
    vfunc = np.vectorize(lambda x: f2())
    s2 = 1 - vfunc(a).sum()/steps
    """
    r = dict()
    t = dict()
    t[name2] = s1 
    r[name1] = t
    """
    t = dict()
    t[name1] = s2 
    r[name2] = t
    """
    return r

# %%
l = list()
l.append(moyenne(h.strategie_aveugle(),h.strategie_optimale(),"aveugle","optimale" ))
l.append(moyenne(h.strategie_aleatoire(),h.strategie_optimale(),"aleatoire","optimale" ))
l.append(moyenne(h.strategie_aleatoire(),h.strategie_aveugle(),"aleatoire","aveugle"))

# %%
print(l)
# Out:
# [{'aveugle': {'optimale': 0.488}, 'optimale': {'aveugle': 0.491}}, {'aleatoire': {'optimale': 0.352}, 'optimale': {'aleatoire': 0.377}}, {'aleatoire': {'aveugle': 0.395}, 'aveugle': {'aleatoire': 0.405}}]
